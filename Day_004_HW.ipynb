# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %% [markdown]
# # [作業目標]
# - 熟悉更多的 Python 資料操作

# %% [markdown]
# # [作業重點]
# - 列出資料的大小 (In[4], Hint : shape)
# - 列出所有欄位 (In[5], 有多種寫法)
# - 擷取部分資料 (In[6], Hint : loc 或 iloc)

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = './data/'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: ./data/application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
app_train.shape
# Out:
# (307511, 122)

# %% [markdown]
# #### 列出所有欄位

# %%
index =  0
for x in app_train.columns:
    print('第{}個欄位名稱為：{}\n'.format( index, x))
    index+=1
# Out:
# 第0個欄位名稱為：SK_ID_CURR
#
# 第1個欄位名稱為：TARGET
#
# 第2個欄位名稱為：NAME_CONTRACT_TYPE
#
# 第3個欄位名稱為：CODE_GENDER
#
# 第4個欄位名稱為：FLAG_OWN_CAR
#
# 第5個欄位名稱為：FLAG_OWN_REALTY
#
# 第6個欄位名稱為：CNT_CHILDREN
#
# 第7個欄位名稱為：AMT_INCOME_TOTAL
#
# 第8個欄位名稱為：AMT_CREDIT
#
# 第9個欄位名稱為：AMT_ANNUITY
#
# 第10個欄位名稱為：AMT_GOODS_PRICE
#
# 第11個欄位名稱為：NAME_TYPE_SUITE
#
# 第12個欄位名稱為：NAME_INCOME_TYPE
#
# 第13個欄位名稱為：NAME_EDUCATION_TYPE
#
# 第14個欄位名稱為：NAME_FAMILY_STATUS
#
# 第15個欄位名稱為：NAME_HOUSING_TYPE
#
# 第16個欄位名稱為：REGION_POPULATION_RELATIVE
#
# 第17個欄位名稱為：DAYS_BIRTH
#
# 第18個欄位名稱為：DAYS_EMPLOYED
#
# 第19個欄位名稱為：DAYS_REGISTRATION
#
# 第20個欄位名稱為：DAYS_ID_PUBLISH
#
# 第21個欄位名稱為：OWN_CAR_AGE
#
# 第22個欄位名稱為：FLAG_MOBIL
#
# 第23個欄位名稱為：FLAG_EMP_PHONE
#
# 第24個欄位名稱為：FLAG_WORK_PHONE
#
# 第25個欄位名稱為：FLAG_CONT_MOBILE
#
# 第26個欄位名稱為：FLAG_PHONE
#
# 第27個欄位名稱為：FLAG_EMAIL
#
# 第28個欄位名稱為：OCCUPATION_TYPE
#
# 第29個欄位名稱為：CNT_FAM_MEMBERS
#
# 第30個欄位名稱為：REGION_RATING_CLIENT
#
# 第31個欄位名稱為：REGION_RATING_CLIENT_W_CITY
#
# 第32個欄位名稱為：WEEKDAY_APPR_PROCESS_START
#
# 第33個欄位名稱為：HOUR_APPR_PROCESS_START
#
# 第34個欄位名稱為：REG_REGION_NOT_LIVE_REGION
#
# 第35個欄位名稱為：REG_REGION_NOT_WORK_REGION
#
# 第36個欄位名稱為：LIVE_REGION_NOT_WORK_REGION
#
# 第37個欄位名稱為：REG_CITY_NOT_LIVE_CITY
#
# 第38個欄位名稱為：REG_CITY_NOT_WORK_CITY
#
# 第39個欄位名稱為：LIVE_CITY_NOT_WORK_CITY
#
# 第40個欄位名稱為：ORGANIZATION_TYPE
#
# 第41個欄位名稱為：EXT_SOURCE_1
#
# 第42個欄位名稱為：EXT_SOURCE_2
#
# 第43個欄位名稱為：EXT_SOURCE_3
#
# 第44個欄位名稱為：APARTMENTS_AVG
#
# 第45個欄位名稱為：BASEMENTAREA_AVG
#
# 第46個欄位名稱為：YEARS_BEGINEXPLUATATION_AVG
#
# 第47個欄位名稱為：YEARS_BUILD_AVG
#
# 第48個欄位名稱為：COMMONAREA_AVG
#
# 第49個欄位名稱為：ELEVATORS_AVG
#
# 第50個欄位名稱為：ENTRANCES_AVG
#
# 第51個欄位名稱為：FLOORSMAX_AVG
#
# 第52個欄位名稱為：FLOORSMIN_AVG
#
# 第53個欄位名稱為：LANDAREA_AVG
#
# 第54個欄位名稱為：LIVINGAPARTMENTS_AVG
#
# 第55個欄位名稱為：LIVINGAREA_AVG
#
# 第56個欄位名稱為：NONLIVINGAPARTMENTS_AVG
#
# 第57個欄位名稱為：NONLIVINGAREA_AVG
#
# 第58個欄位名稱為：APARTMENTS_MODE
#
# 第59個欄位名稱為：BASEMENTAREA_MODE
#
# 第60個欄位名稱為：YEARS_BEGINEXPLUATATION_MODE
#
# 第61個欄位名稱為：YEARS_BUILD_MODE
#
# 第62個欄位名稱為：COMMONAREA_MODE
#
# 第63個欄位名稱為：ELEVATORS_MODE
#
# 第64個欄位名稱為：ENTRANCES_MODE
#
# 第65個欄位名稱為：FLOORSMAX_MODE
#
# 第66個欄位名稱為：FLOORSMIN_MODE
#
# 第67個欄位名稱為：LANDAREA_MODE
#
# 第68個欄位名稱為：LIVINGAPARTMENTS_MODE
#
# 第69個欄位名稱為：LIVINGAREA_MODE
#
# 第70個欄位名稱為：NONLIVINGAPARTMENTS_MODE
#
# 第71個欄位名稱為：NONLIVINGAREA_MODE
#
# 第72個欄位名稱為：APARTMENTS_MEDI
#
# 第73個欄位名稱為：BASEMENTAREA_MEDI
#
# 第74個欄位名稱為：YEARS_BEGINEXPLUATATION_MEDI
#
# 第75個欄位名稱為：YEARS_BUILD_MEDI
#
# 第76個欄位名稱為：COMMONAREA_MEDI
#
# 第77個欄位名稱為：ELEVATORS_MEDI
#
# 第78個欄位名稱為：ENTRANCES_MEDI
#
# 第79個欄位名稱為：FLOORSMAX_MEDI
#
# 第80個欄位名稱為：FLOORSMIN_MEDI
#
# 第81個欄位名稱為：LANDAREA_MEDI
#
# 第82個欄位名稱為：LIVINGAPARTMENTS_MEDI
#
# 第83個欄位名稱為：LIVINGAREA_MEDI
#
# 第84個欄位名稱為：NONLIVINGAPARTMENTS_MEDI
#
# 第85個欄位名稱為：NONLIVINGAREA_MEDI
#
# 第86個欄位名稱為：FONDKAPREMONT_MODE
#
# 第87個欄位名稱為：HOUSETYPE_MODE
#
# 第88個欄位名稱為：TOTALAREA_MODE
#
# 第89個欄位名稱為：WALLSMATERIAL_MODE
#
# 第90個欄位名稱為：EMERGENCYSTATE_MODE
#
# 第91個欄位名稱為：OBS_30_CNT_SOCIAL_CIRCLE
#
# 第92個欄位名稱為：DEF_30_CNT_SOCIAL_CIRCLE
#
# 第93個欄位名稱為：OBS_60_CNT_SOCIAL_CIRCLE
#
# 第94個欄位名稱為：DEF_60_CNT_SOCIAL_CIRCLE
#
# 第95個欄位名稱為：DAYS_LAST_PHONE_CHANGE
#
# 第96個欄位名稱為：FLAG_DOCUMENT_2
#
# 第97個欄位名稱為：FLAG_DOCUMENT_3
#
# 第98個欄位名稱為：FLAG_DOCUMENT_4
#
# 第99個欄位名稱為：FLAG_DOCUMENT_5
#
# 第100個欄位名稱為：FLAG_DOCUMENT_6
#
# 第101個欄位名稱為：FLAG_DOCUMENT_7
#
# 第102個欄位名稱為：FLAG_DOCUMENT_8
#
# 第103個欄位名稱為：FLAG_DOCUMENT_9
#
# 第104個欄位名稱為：FLAG_DOCUMENT_10
#
# 第105個欄位名稱為：FLAG_DOCUMENT_11
#
# 第106個欄位名稱為：FLAG_DOCUMENT_12
#
# 第107個欄位名稱為：FLAG_DOCUMENT_13
#
# 第108個欄位名稱為：FLAG_DOCUMENT_14
#
# 第109個欄位名稱為：FLAG_DOCUMENT_15
#
# 第110個欄位名稱為：FLAG_DOCUMENT_16
#
# 第111個欄位名稱為：FLAG_DOCUMENT_17
#
# 第112個欄位名稱為：FLAG_DOCUMENT_18
#
# 第113個欄位名稱為：FLAG_DOCUMENT_19
#
# 第114個欄位名稱為：FLAG_DOCUMENT_20
#
# 第115個欄位名稱為：FLAG_DOCUMENT_21
#
# 第116個欄位名稱為：AMT_REQ_CREDIT_BUREAU_HOUR
#
# 第117個欄位名稱為：AMT_REQ_CREDIT_BUREAU_DAY
#
# 第118個欄位名稱為：AMT_REQ_CREDIT_BUREAU_WEEK
#
# 第119個欄位名稱為：AMT_REQ_CREDIT_BUREAU_MON
#
# 第120個欄位名稱為：AMT_REQ_CREDIT_BUREAU_QRT
#
# 第121個欄位名稱為：AMT_REQ_CREDIT_BUREAU_YEAR

# %% [markdown]
# #### 截取部分資料

# %%
app_train.iloc[5:18, 15:18]
# Out:
#     NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH
# 5   House / apartment                    0.035792      -16941
# 6   House / apartment                    0.035792      -13778
# 7   House / apartment                    0.003122      -18850
# 8   House / apartment                    0.018634      -20099
# 9   House / apartment                    0.019689      -14469
# 10  House / apartment                    0.022800      -10197
# 11  House / apartment                    0.015221      -20417
# 12  House / apartment                    0.031329      -13439
# 13  House / apartment                    0.016612      -14086
# 14  House / apartment                    0.010006      -14583
# 15   Rented apartment                    0.020713       -8728
# 16  House / apartment                    0.018634      -12931
# 17  House / apartment                    0.010966       -9776

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子
